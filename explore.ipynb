# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import itertools
from datetime import date

from scipy import stats
import sklearn.preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

import wrangle as wr
import explore as ex
# %matplotlib inline

# %% [markdown]
# ### Q1:
# #### Train, Validate, Test split

# %%
train, validate, test = wr.wrangle_zillow()
train.shape, validate.shape, test.shape
# Out:
# ((927671, 7), (397574, 7), (331312, 7))

# %%
# Dataset too large for timely visualization, creating subset
train = train[:5000]
train.head()
# Out:
#          bedrooms  bathrooms    area  tax_value year_built    fips  yearly_tax
# 1462930       3.0        2.0  1385.0   123859.0     1956.0  6059.0      1906.0
# 1842132       4.0        2.0  1567.0   251569.0     1946.0  6037.0      3354.0
# 869730        4.0        2.0  1910.0   762153.0     1958.0  6059.0     12098.0
# 1306111       3.0        2.0  2042.0   751716.0     1936.0  6037.0      8844.0
# 431629        3.0        2.0  1502.0   351732.0     1956.0  6037.0      5411.0

# %% [markdown]
# ### Q2:
# #### `plot_variable_pairs`

# %%
# In the exercises called plot_variable_pairs, renamed so as to identify what kind of plot
ex.lmplot_variable_pairs(train)
# Out:
# _____________________________________________
# _____________________________________________
# _____________________________________________
# _____________________________________________
# _____________________________________________
# _____________________________________________

# %% [markdown]
# ### Q3:
# #### `months_to_years`

# %%
# Created variable yearly_tax in my wrangle file as it fits into prepare:
    ## Getting current year
    # curr_year = int(f'{str(date.today())[:4]}')

    ## Creating column
    # df['yearly_tax'] = df.tax_value / (curr_year - df.year_built)
    
    ## Casting as a rounded float
    #df.yearly_tax = round(df.yearly_tax.astype(float), 0)
wr.yearly_tax(wr.prepare_zillow())
train.head()
# Out:
#          bedrooms  bathrooms    area  tax_value year_built    fips  yearly_tax
# 1462930       3.0        2.0  1385.0   123859.0     1956.0  6059.0      1906.0
# 1842132       4.0        2.0  1567.0   251569.0     1946.0  6037.0      3354.0
# 869730        4.0        2.0  1910.0   762153.0     1958.0  6059.0     12098.0
# 1306111       3.0        2.0  2042.0   751716.0     1936.0  6037.0      8844.0
# 431629        3.0        2.0  1502.0   351732.0     1956.0  6037.0      5411.0

# %% [markdown]
# ### Q4:
# #### `plot_categorical_and_continuous_vars`

# %%
# Iterate trought list of cat/quant pairs, feature combos, and quant combos to come up with 
# relplots, lmplots, heatmaps, and pairplots for dataset
ex.plot_categorical_and_continuous_vars(train)
# Out:
# Relplots for each cat/quant feature pairing
# _____________________________________________
# _____________________________________________
# _____________________________________________
# _____________________________________________
# _____________________________________________
# _____________________________________________
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Lmplots for each cat/quant feature pairing
# _____________________________________________
# _____________________________________________
# _____________________________________________
# _____________________________________________
# _____________________________________________
# _____________________________________________
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Jointplots for each cat/quant feature pairing
# _____________________________________________
# _____________________________________________
# _____________________________________________
# ...
